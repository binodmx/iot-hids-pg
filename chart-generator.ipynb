# %%
models = ["gemma:2b", "llama2:7b", "gpt-3.5"]

# %%
# bot iot 

# Predicting for attack type: DDoS_HTTP
# Num tokens: 4415
# Predicting benign samples...
# Predicting attack samples...
#               precision    recall  f1-score   support

#       ATTACK       0.74      1.00      0.85        25
#       BENIGN       1.00      0.64      0.78        25

#     accuracy                           0.82        50
#    macro avg       0.87      0.82      0.81        50
# weighted avg       0.87      0.82      0.81        50

# ton iot ----------------------------------------------------------------------

#               precision    recall  f1-score   support

#       ATTACK       0.75      0.96      0.84        25
#       BENIGN       0.94      0.68      0.79        25

#     accuracy                           0.82        50
#    macro avg       0.85      0.82      0.82        50
# weighted avg       0.85      0.82      0.82        50

# edge-iiot --------------------------------------------------------------------

# Predicting for attack type: DDoS_HTTP
# Num tokens: 13085
# Predicting benign samples...
# Predicting attack samples...
#               precision    recall  f1-score   support

#       ATTACK       0.60      1.00      0.75        25
#       BENIGN       1.00      0.32      0.48        25

#     accuracy                           0.66        50
#    macro avg       0.80      0.66      0.62        50
# weighted avg       0.80      0.66      0.62        50

# %%
datasets = ["bot-iot", "ton-iot", "edge-iiot"]

benign_precisions = [1.00, 0.94, 1.00]
attack_precisions = [0.74, 0.75, 0.60]

benign_recalls = [0.64, 0.68, 0.32]
attack_recalls = [1.00, 0.96, 1.00]

benign_f1s = [0.78, 0.79, 0.48]
attack_f1s = [0.85, 0.84, 0.75]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))
bar_width = 0.2
x = np.arange(len(datasets))
plt.bar(x - bar_width/2, benign_precisions, bar_width, label="Benign", color="green")
plt.bar(x + bar_width/2, attack_precisions, bar_width, label="Attack", color="red")

plt.title("Precision of Benign and Attack Samples (gpt-3.5)", fontsize=18)
plt.xlabel("Datasets", fontsize=16)
plt.ylabel("Precision", fontsize=16)
plt.legend()
plt.xticks(x, datasets)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('legend', fontsize=16)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))
bar_width = 0.2
x = np.arange(len(datasets))
plt.bar(x - bar_width/2, benign_recalls, bar_width, label="Benign", color="green")
plt.bar(x + bar_width/2, attack_recalls, bar_width, label="Attack", color="red")

plt.title("Recall of Benign and Attack Samples (gpt-3.5)", fontsize=18)
plt.xlabel("Datasets", fontsize=16)
plt.ylabel("Recall", fontsize=16)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('legend', fontsize=16)
plt.legend()
plt.xticks(x, datasets)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))
bar_width = 0.2
x = np.arange(len(datasets))
plt.bar(x - bar_width/2, benign_f1s, bar_width, label="Benign", color="green")
plt.bar(x + bar_width/2, attack_f1s, bar_width, label="Attack", color="red")

plt.title("F1-score of Benign and Attack Samples (gpt-3.5)", fontsize=18)
plt.xlabel("Datasets", fontsize=16)
plt.ylabel("F1-score", fontsize=16)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('legend', fontsize=16)
plt.ylim(0, 1)
plt.legend()
plt.xticks(x, datasets)
plt.show()
