# %% [markdown]
# **Dataset Info**
#
# - Paper: CICIoT2023: A Real-Time Dataset and Benchmark for Large-Scale Attacks in IoT Environment
# - Published in: MDPI Sensors 2023
# - Date: 26 June 2023
# - Links:
#     - https://www.mdpi.com/1424-8220/23/13/5941
#     - https://www.unb.ca/cic/datasets/iotdataset-2023.html

# %%
import os
import pandas as pd

path = os.getcwd() + '/../data/cic-iot/CSV/'
dfs = [pd.read_csv(path + file_name) for file_name in os.listdir(path)[:2] if file_name.endswith('.csv')]
df = pd.concat(dfs, ignore_index=True)

# %%
# df = pd.read_csv(os.getcwd() + '/../data/cic-iot/CSV/part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv')
print("No of Featueres: ", len(df.columns))
print("Features: ", df.columns)
# Out:
# No of Featueres:  47
# Features:  Index(['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate',
#        'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number',
#        'rst_flag_number', 'psh_flag_number', 'ack_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count',
#        'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet',
#        'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC',
#        'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT', 'Number',
#        'Magnitue', 'Radius', 'Covariance', 'Variance', 'Weight', 'label'],
#       dtype='object')

# %%
import json

# print 1st record as a pretty json along with column names
print("1st record: ", json.dumps(df.iloc[0].to_dict(), indent=4))
# Out:
# 1st record:  {
#     "flow_duration": 0.0008969092369079,
#     "Header_Length": 57.22,
#     "Protocol Type": 6.11,
#     "Duration": 64.64,
#     "Rate": 22.085110790785848,
#     "Srate": 22.085110790785848,
#     "Drate": 0.0,
#     "fin_flag_number": 0.0,
#     "syn_flag_number": 1.0,
#     "rst_flag_number": 0.0,
#     "psh_flag_number": 0.0,
#     "ack_flag_number": 0.0,
#     "ece_flag_number": 0.0,
#     "cwr_flag_number": 0.0,
#     "ack_count": 0.0,
#     "syn_count": 0.99,
#     "fin_count": 0.0,
#     "urg_count": 0.0,
#     "rst_count": 0.0,
#     "HTTP": 0.0,
#     "HTTPS": 0.0,
#     "DNS": 0.0,
#     "Telnet": 0.0,
#     "SMTP": 0.0,
#     "SSH": 0.0,
#     "IRC": 0.0,
#     "TCP": 1.0,
#     "UDP": 0.0,
#     "DHCP": 0.0,
#     "ARP": 0.0,
#     "ICMP": 0.0,
#     "IPv": 1.0,
#     "LLC": 1.0,
#     "Tot sum": 592.74,
#     "Min": 54.0,
#     "Max": 79.74,
#     "AVG": 55.7989250834305,
#     "Std": 6.516845173742946,
#     "Tot size": 56.34,
#     "IAT": 83089048.97824158,
#     "Number": 9.5,
#     "Magnitue": 10.554078060697275,
#     "Radius": 9.233921758666606,
#     "Covariance": 391.3616032280932,
#     "Variance": 0.11,
#     "Weight": 141.55,
#     "label": "DDoS-SYN_Flood"
# }

# %%
# print describe of the dataset in pretty json
print(json.dumps(df.describe().to_dict(), indent=4))
# Out:
# {
#     "flow_duration": {
#         "count": 454268.0,
#         "mean": 5.273333689611606,
#         "std": 237.94965270332744,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.10430913090705865,
#         "max": 64237.678451776505
#     },
#     "Header_Length": {
#         "count": 454268.0,
#         "mean": 76105.88860476368,
#         "std": 458951.8143554,
#         "min": 0.0,
#         "25%": 54.0,
#         "50%": 54.0,
#         "75%": 250.43,
#         "max": 9784666.6
#     },
#     "Protocol Type": {
#         "count": 454268.0,
#         "mean": 9.06557537548041,
#         "std": 8.964651868292927,
#         "min": 0.0,
#         "25%": 6.0,
#         "50%": 6.0,
#         "75%": 13.8,
#         "max": 47.0
#     },
#     "Duration": {
#         "count": 454268.0,
#         "mean": 66.34202302556143,
#         "std": 13.99935345069542,
#         "min": 0.0,
#         "25%": 64.0,
#         "50%": 64.0,
#         "75%": 64.0,
#         "max": 255.0
#     },
#     "Rate": {
#         "count": 454268.0,
#         "mean": 8850.104868780641,
#         "std": 95754.52070037484,
#         "min": 0.0,
#         "25%": 2.0861799451962346,
#         "50%": 15.649463496359072,
#         "75%": 115.93520924318648,
#         "max": 6291456.0
#     },
#     "Srate": {
#         "count": 454268.0,
#         "mean": 8850.104868780641,
#         "std": 95754.52070037484,
#         "min": 0.0,
#         "25%": 2.0861799451962346,
#         "50%": 15.649463496359072,
#         "75%": 115.93520924318648,
#         "max": 6291456.0
#     },
#     "Drate": {
#         "count": 454268.0,
#         "mean": 1.4844092368915977e-05,
#         "std": 0.006537464264300666,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 4.3056038597751884
#     },
#     "fin_flag_number": {
#         "count": 454268.0,
#         "mean": 0.08628386767282749,
#         "std": 0.28078307535227187,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "syn_flag_number": {
#         "count": 454268.0,
#         "mean": 0.20758450958465047,
#         "std": 0.40557803573662055,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "rst_flag_number": {
#         "count": 454268.0,
#         "mean": 0.09012741377336726,
#         "std": 0.28636452919364336,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "psh_flag_number": {
#         "count": 454268.0,
#         "mean": 0.08843458046791762,
#         "std": 0.28392619270628167,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "ack_flag_number": {
#         "count": 454268.0,
#         "mean": 0.12385199926034851,
#         "std": 0.32941299369301885,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "ece_flag_number": {
#         "count": 454268.0,
#         "mean": 0.0,
#         "std": 0.0,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 0.0
#     },
#     "cwr_flag_number": {
#         "count": 454268.0,
#         "mean": 0.0,
#         "std": 0.0,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 0.0
#     },
#     "ack_count": {
#         "count": 454268.0,
#         "mean": 0.09016027573163797,
#         "std": 0.2858802263125994,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 4.1
#     },
#     "syn_count": {
#         "count": 454268.0,
#         "mean": 0.3305823725030339,
#         "std": 0.664153992553724,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.06,
#         "max": 12.87
#     },
#     "fin_count": {
#         "count": 454268.0,
#         "mean": 0.09855516956065483,
#         "std": 0.29899081585268644,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 22.3
#     },
#     "urg_count": {
#         "count": 454268.0,
#         "mean": 6.230777607307452,
#         "std": 71.9760961967652,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 3081.0
#     },
#     "rst_count": {
#         "count": 454268.0,
#         "mean": 38.37802878139683,
#         "std": 326.70800597719796,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.01,
#         "max": 8868.5
#     },
#     "HTTP": {
#         "count": 454268.0,
#         "mean": 0.048004702070143616,
#         "std": 0.21377640480530277,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "HTTPS": {
#         "count": 454268.0,
#         "mean": 0.05466596810693247,
#         "std": 0.2273273274339757,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "DNS": {
#         "count": 454268.0,
#         "mean": 0.00013868465311225972,
#         "std": 0.011775641168538157,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "Telnet": {
#         "count": 454268.0,
#         "mean": 0.0,
#         "std": 0.0,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 0.0
#     },
#     "SMTP": {
#         "count": 454268.0,
#         "mean": 0.0,
#         "std": 0.0,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 0.0
#     },
#     "SSH": {
#         "count": 454268.0,
#         "mean": 4.6228217704086575e-05,
#         "std": 0.006798983925241325,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "IRC": {
#         "count": 454268.0,
#         "mean": 0.0,
#         "std": 0.0,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 0.0
#     },
#     "TCP": {
#         "count": 454268.0,
#         "mean": 0.5743569875051732,
#         "std": 0.4944406704298509,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 1.0,
#         "75%": 1.0,
#         "max": 1.0
#     },
#     "UDP": {
#         "count": 454268.0,
#         "mean": 0.21086671304164062,
#         "std": 0.40792439088797927,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "DHCP": {
#         "count": 454268.0,
#         "mean": 2.2013437001945987e-06,
#         "std": 0.0014836925895193385,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "ARP": {
#         "count": 454268.0,
#         "mean": 3.9624186603502777e-05,
#         "std": 0.006294656761931351,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "ICMP": {
#         "count": 454268.0,
#         "mean": 0.16389003847948788,
#         "std": 0.37017616808443726,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.0,
#         "max": 1.0
#     },
#     "IPv": {
#         "count": 454268.0,
#         "mean": 0.9999185502830928,
#         "std": 0.009024592075846303,
#         "min": 0.0,
#         "25%": 1.0,
#         "50%": 1.0,
#         "75%": 1.0,
#         "max": 1.0
#     },
#     "LLC": {
#         "count": 454268.0,
#         "mean": 0.9999185502830928,
#         "std": 0.009024592075846303,
#         "min": 0.0,
#         "25%": 1.0,
#         "50%": 1.0,
#         "75%": 1.0,
#         "max": 1.0
#     },
#     "Tot sum": {
#         "count": 454268.0,
#         "mean": 1301.8286818236365,
#         "std": 2587.5382100597412,
#         "min": 42.0,
#         "25%": 525.0,
#         "50%": 567.0,
#         "75%": 567.54,
#         "max": 69246.6
#     },
#     "Min": {
#         "count": 454268.0,
#         "mean": 91.43791626828867,
#         "std": 138.96030611220093,
#         "min": 42.0,
#         "25%": 50.0,
#         "50%": 54.0,
#         "75%": 54.0,
#         "max": 3266.0
#     },
#     "Max": {
#         "count": 454268.0,
#         "mean": 181.13817338317241,
#         "std": 524.2373268284226,
#         "min": 42.0,
#         "25%": 50.0,
#         "50%": 54.0,
#         "75%": 55.24,
#         "max": 49014.0
#     },
#     "AVG": {
#         "count": 454268.0,
#         "mean": 124.31416460318957,
#         "std": 240.11486220489553,
#         "min": 42.0,
#         "25%": 50.0,
#         "50%": 54.0,
#         "75%": 54.048177631578945,
#         "max": 6221.9548412698405
#     },
#     "Std": {
#         "count": 454268.0,
#         "mean": 33.12468370376085,
#         "std": 160.66440991663353,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.3719095500603566,
#         "max": 12385.2391048564
#     },
#     "Tot size": {
#         "count": 454268.0,
#         "mean": 124.34866376343555,
#         "std": 240.85050231579442,
#         "min": 42.0,
#         "25%": 50.0,
#         "50%": 54.0,
#         "75%": 54.06,
#         "max": 7262.4
#     },
#     "IAT": {
#         "count": 454268.0,
#         "mean": 83145956.36546376,
#         "std": 16980774.477460913,
#         "min": 0.0,
#         "25%": 83071566.98639335,
#         "50%": 83124526.89705229,
#         "75%": 83343901.53533286,
#         "max": 167639420.82016832
#     },
#     "Number": {
#         "count": 454268.0,
#         "mean": 9.49658551019016,
#         "std": 0.8168851292535679,
#         "min": 1.0,
#         "25%": 9.5,
#         "50%": 9.5,
#         "75%": 9.5,
#         "max": 13.5
#     },
#     "Magnitue": {
#         "count": 454268.0,
#         "mean": 13.108697671626443,
#         "std": 8.607241037094228,
#         "min": 9.165151389911678,
#         "25%": 10.0,
#         "50%": 10.392304845413264,
#         "75%": 10.396634160500465,
#         "max": 107.46117453694346
#     },
#     "Radius": {
#         "count": 454268.0,
#         "mean": 46.80775523857062,
#         "std": 227.21858336672864,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.5059212763185684,
#         "max": 17551.27080917445
#     },
#     "Covariance": {
#         "count": 454268.0,
#         "mean": 30915.24521806462,
#         "std": 395178.1645178556,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 1.3289440584565242,
#         "max": 154902159.24774638
#     },
#     "Variance": {
#         "count": 454268.0,
#         "mean": 0.09610931459293769,
#         "std": 0.2325039892332312,
#         "min": 0.0,
#         "25%": 0.0,
#         "50%": 0.0,
#         "75%": 0.08,
#         "max": 1.0
#     },
#     "Weight": {
#         "count": 454268.0,
#         "mean": 141.46567254864127,
#         "std": 20.99508086730522,
#         "min": 1.0,
#         "25%": 141.55,
#         "50%": 141.55,
#         "75%": 141.55,
#         "max": 244.6
#     }
# }

# %%
print("No of classes: ", len(df['label'].unique()))
print(df['label'].unique())
# Out:
# No of classes:  34
# ['DDoS-SYN_Flood' 'DDoS-SynonymousIP_Flood' 'DDoS-ICMP_Flood'
#  'DDoS-TCP_Flood' 'DDoS-UDP_Flood' 'DDoS-PSHACK_Flood' 'DDoS-RSTFINFlood'
#  'Mirai-greip_flood' 'DoS-SYN_Flood' 'DoS-UDP_Flood' 'DoS-TCP_Flood'
#  'BenignTraffic' 'Mirai-udpplain' 'DDoS-UDP_Fragmentation'
#  'DDoS-ICMP_Fragmentation' 'Mirai-greeth_flood' 'DNS_Spoofing'
#  'Recon-OSScan' 'MITM-ArpSpoofing' 'DDoS-ACK_Fragmentation'
#  'DDoS-HTTP_Flood' 'Recon-HostDiscovery' 'DoS-HTTP_Flood' 'Recon-PortScan'
#  'CommandInjection' 'VulnerabilityScan' 'Recon-PingSweep' 'DDoS-SlowLoris'
#  'DictionaryBruteForce' 'SqlInjection' 'XSS' 'BrowserHijacking'
#  'Backdoor_Malware' 'Uploading_Attack']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 6))
plt.xticks(rotation=90)
s = sns.countplot(data=df, x='label', hue='label')
for p in s.patches:
    s.annotate(format(p.get_height(), '.0f'), 
               (p.get_x() + p.get_width() / 2., p.get_height()), 
               ha = 'center', va = 'center', 
               xytext = (0, 9), 
               textcoords = 'offset points')
plt.title('Record Count', fontsize=20)

plt.show()

# %%
# remove duplicate rows
df_no_duplicates = df.drop_duplicates()
# print length of dataset after removing duplicates
print("Length of dataset before removing duplicates: ", len(df))
print("Length of dataset after removing duplicates: ", len(df_no_duplicates))
# Out:
# Length of dataset before removing duplicates:  454268
# Length of dataset after removing duplicates:  454268
